# %% [markdown]
# ## Welcome to the Second class of ArcPy
# #### These words are written in "Markdown".
# ##### Double click me and you will see the pound signs in the front of each line.

# %%
import arcpy, arcgis, sys, os
# I like to load all the modules at once... not good practice, though...

# %% [markdown]
# References:
# * Great explanation on how to use [the Jupyter notebook environment](https://developers.arcgis.com/python/guide/using-the-jupyter-notebook-environment/)
# * A blog post [five tips to get started with Jupyte Notebook](https://blogs.esri.com/esri/arcgis/2017/06/30/82220/) for more tips and patterns to follow.

# %%
from IPython.display import Image
#from IPython.core.display import HTML 
#Image(url= "http://my_site.com/my_picture.jpg")
Image(r"C:\Users\Skenny02\Pictures\ringebu.jpg", width=200)

# %%
name = input("What is your name?  ")
print (f"Hello, {name}!")
xx = eval(input("Enter a math problem.  For example: 2 + 2      "))
print(xx)
# Out:
# What is your name?  Sdk
# Hello, Sdk!
# Enter a math problem.  For example: 2 + 2      4
# 4

# %%
# Below is Python 2.7 code

print "Hello!"

x = 2
xx = "? "
bb = "Can we fix Python"
tt = raw_input(bb+xx)

yy = "%s %d.7 %s %s." % (bb,x,xx,tt)

print yy
# Out:
#   File "<ipython-input-4-8be297fbe67a>", line 1
#     print "Hello!"
#                  ^
# SyntaxError: Missing parentheses in call to 'print'

# %% [markdown]
# ## Creating and writing a file

# %%
# the w below, if an x, will not over write the file.
bb = open("gisss.txt", 'w')
bb.write("""Hi, Hello!""")
bb.close()

# %%
# Run the above again and you will see the error
# because the file already exists

# %%
cc = open("gisss.txt", 'r')
cc.read()
# Out:
# 'Hi, Hello!'

# %% [raw]
# def f(x):
#     """a docstring"""
#     return x**2
#
# # This code is in Raw NB convert so it looks pretty

# %% [markdown]
# ## This one is in Markdown

# %%
# Lets use the 2to3 module to fix scripts
